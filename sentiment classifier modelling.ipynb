# %%
# imports
##
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

from scipy.sparse import coo_matrix, hstack

import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

import tqdm
from tqdm import trange

# %%
# Read in the data
##
tweets = pd.read_csv("csv files/tweets.csv")

# %%
# Preview data
##
tweets.head()
# Out:
#               tweet_id                                               text  \
# 0  1242123434466979841  everyday might good there always something goo...
# 1  1242123396684697603                                      next one week
# 2  1242123373188124673             imagine people coming self something h
# 3  1242086219519012867                   never forget remind fight corona
# 4  1242123367882330113       they provide food outdoor step well quarante
#
#             created_at  likes  text length  polarity
# 0  2020-03-23 16:17:58      1           57       0.4
# 1  2020-03-23 16:17:49      0           13       0.0
# 2  2020-03-23 16:17:44      0           38       0.0
# 3  2020-03-23 13:50:06      0           32       0.0
# 4  2020-03-23 16:17:43      0           44       0.0

# %%
tweets.tail()
# Out:
#                  tweet_id                                               text  \
# 1185  1242064075405905921  emergency response team sent trace catholic pr...
# 1186  1242064012797530112                  time put mandatory hate happening
# 1187  1242063970632163329    people lose trust governing becomes face choice
# 1188  1242063856727396352                               incompetent wont die
# 1189  1242063643883307008  next corona virus strain even deadly see lippi...
#
#                created_at  likes  text length  polarity
# 1185  2020-03-23 12:22:06      4           73  0.113636
# 1186  2020-03-23 12:21:51      1           33 -0.800000
# 1187  2020-03-23 12:21:41      1           47  0.000000
# 1188  2020-03-23 12:21:14      2           20 -0.350000
# 1189  2020-03-23 12:20:23      1           58 -0.100000

# %% [markdown]
# # EDA
# Exploring the data

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tweet_id     1190 non-null   int64
#  1   text         1182 non-null   object
#  2   created_at   1190 non-null   object
#  3   likes        1190 non-null   int64
#  4   text length  1190 non-null   int64
#  5   polarity     1190 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 55.9+ KB

# %%
tweets.describe().T
# Out:
#               count          mean           std           min           25%  \
# tweet_id     1190.0  1.242092e+18  1.612207e+13  1.242064e+18  1.242078e+18
# likes        1190.0  9.109244e-01  1.320269e+00  0.000000e+00  0.000000e+00
# text length  1190.0  3.597059e+01  1.683447e+01  0.000000e+00  2.300000e+01
# polarity     1190.0  5.597235e-02  2.477956e-01 -1.000000e+00  0.000000e+00
#
#                       50%           75%           max
# tweet_id     1.242092e+18  1.242103e+18  1.242123e+18
# likes        1.000000e+00  1.000000e+00  1.100000e+01
# text length  3.650000e+01  4.800000e+01  8.500000e+01
# polarity     0.000000e+00  1.363636e-01  1.000000e+00

# %%
# Checking for missing data
##
if tweets.isnull().values.any() == True:
    print("There is missing data. \nThe missing data points are as follows:\n", tweets.isnull().sum())
else:
    print("There is no missing data points.")
# Out:
# There is missing data.
# The missing data points are as follows:
#  tweet_id       0
# text           8
# created_at     0
# likes          0
# text length    0
# polarity       0
# dtype: int64

# %%
# Dropping the missing data points row-wise
##
tweets.dropna(axis=0, inplace=True)

# %%
# Reset index
##
tweets.reset_index(drop=True, inplace=True)

# %%
# Distribution of text length
##
sns.distplot(tweets['text length'])

# %%
# No. of unique number_of_likes and the corresponding count
##
tweets['likes'].value_counts()
# Out:
# 0     587
# 1     341
# 2     150
# 3      49
# 4      31
# 6       8
# 5       6
# 7       4
# 10      2
# 8       2
# 11      1
# 9       1
# Name: likes, dtype: int64

# %%
# Countplot of tweet likes
##
sns.countplot(x=tweets['likes'])

# %% [markdown]
# ## Feature Engineering

# %%
# Let's classify sentiment as negative, neutral or positive
##
tweets['sentiment'] = np.nan

for i in trange(len(tweets)):
    if tweets['polarity'][i] < 0:
        tweets['sentiment'][i] = 'negative'
    elif tweets['polarity'][i] == 0:
        tweets['sentiment'][i] = 'neutral'
    else:
        tweets['sentiment'][i] = 'positive'

# Preview tweets
tweets.sample(15)
# Out:
# 100%|██████████| 1182/1182 [00:00<00:00, 6781.70it/s]
#                 tweet_id                                               text  \
# 425  1242103801907154947           president free market free business test
# 573  1242098182944940037  indeed total black urge contact fare personall...
# 872  1242086825872764928                          g looked may moment brace
# 120  1242118615232626688                                    born resist god
# 501  1242087101094596610        going tough time apart employer acknowledge
# 12   1242123153939353600                           still open whatever need
# 106  1242119607617564673      support fight could safety shop alcohol based
# 826  1242089320460292099               really care period hard time virus w
# 638  1242096325031854082                                   stay home people
# 92   1242120156626792456                                        work home a
# 165  1242116656706605058                             click link thank later
# 104  1242119806586945539               afraid could anaemic workplace could
# 234  1242066305827643393                          getting necessary support
# 676  1242095041721577475                              catholic church bunch
# 240  1242083121627107340              march president agreement look access
#
#               created_at  likes  text length  polarity sentiment
# 425  2020-03-23 14:59:58      0           40  0.400000  positive
# 573  2020-03-23 14:37:38      1           66 -0.055556  negative
# 872  2020-03-23 13:52:30      2           25  0.000000   neutral
# 120  2020-03-23 15:58:49      0           15  0.000000   neutral
# 501  2020-03-23 13:53:36      0           43 -0.388889  negative
# 12   2020-03-23 16:16:52      0           24  0.000000   neutral
# 106  2020-03-23 16:02:46      0           45  0.000000   neutral
# 826  2020-03-23 14:02:25      0           36 -0.045833  negative
# 638  2020-03-23 14:30:15      1           16  0.000000   neutral
# 92   2020-03-23 16:04:57      1           11  0.000000   neutral
# 165  2020-03-23 15:51:03      0           22  0.000000   neutral
# 104  2020-03-23 16:03:34      0           36 -0.600000  negative
# 234  2020-03-23 12:30:58      0           25  0.000000   neutral
# 676  2020-03-23 14:25:09      1           21  0.000000   neutral
# 240  2020-03-23 13:37:47      0           37  0.000000   neutral

# %%
# Creating the target variable based off of the sentiment column
##
mapper = {
    'negative': -1,
    'neutral': 0,
    'positive': 1
}

tweets['target'] = tweets['sentiment'].map(mapper)

# Preview
tweets.sample(15)
# Out:
#                 tweet_id                                               text  \
# 611  1242097130560540674  see running usual carelessly without observing...
# 346  1242107352729432067                      coming village quarante force
# 589  1242066448488566784  pie love much perfect dish simple quick delici...
# 318  1242108064456720384                    hilarious message home sanitize
# 868  1242087084720095233  tough arrogance section continue cost u dearly...
# 424  1242103806554443776                            penniless wont turn mug
# 508  1242086686814855173  crisis like outbreak remind u truly together c...
# 669  1242095114555740168  can government fuel price sort menace current ...
# 170  1242116301352513538     good enough really thought moderate human face
# 371  1242106005321920513              continue praying nation woman le week
# 322  1242108011260362752                 president supposed food faster got
# 696  1242094439843205120                                  oh could shutting
# 790  1242090766819823618  could anaemic collected waste health hazard ke...
# 727  1242093091223408640                                 share relate could
# 218  1242067316248055808   search going came contact catholic priest burial
#
#               created_at  likes  text length  polarity sentiment  target
# 611  2020-03-23 14:33:27      1           58 -0.238889  negative      -1
# 346  2020-03-23 15:14:04      0           29  0.000000   neutral       0
# 589  2020-03-23 12:31:32      4           53  0.566667  positive       1
# 318  2020-03-23 15:16:54      0           31  0.500000  positive       1
# 868  2020-03-23 13:53:32      0           58 -0.388889  negative      -1
# 424  2020-03-23 14:59:59      0           23  0.000000   neutral       0
# 508  2020-03-23 13:51:57      1           50  0.000000   neutral       0
# 669  2020-03-23 14:25:26      1           55  0.000000   neutral       0
# 170  2020-03-23 15:49:38      2           46  0.180000  positive       1
# 371  2020-03-23 15:08:43      1           37  0.000000   neutral       0
# 322  2020-03-23 15:16:41      1           34  0.000000   neutral       0
# 696  2020-03-23 14:22:46      2           17  0.000000   neutral       0
# 790  2020-03-23 14:08:10      0           53  0.150000  positive       1
# 727  2020-03-23 14:17:24      0           18  0.000000   neutral       0
# 218  2020-03-23 12:34:59      0           48  0.000000   neutral       0

# %%
# Create another feature wordcount and compare its distribution with that of text length
# to see which best fits as a feature to be used in the model
##
tweets['word count'] = tweets['text'].apply(lambda text: len(text.split()))

# %%
# Comparing the two distributions
##
fig, axes = plt.subplots(ncols=2, figsize=(10,4))

sns.distplot(tweets['text length'], ax=axes[0])
axes[0].set_title("Distribution of text length")

sns.distplot(tweets['word count'], ax=axes[1])
axes[1].set_title("Distribution of word count")

plt.tight_layout()

# %% [markdown]
# Seems that the two distributions have an identical pattern
# We'll use both features in the model building phase

# %%
tweets.head()
# Out:
#               tweet_id                                               text  \
# 0  1242123434466979841  everyday might good there always something goo...
# 1  1242123396684697603                                      next one week
# 2  1242123373188124673             imagine people coming self something h
# 3  1242086219519012867                   never forget remind fight corona
# 4  1242123367882330113       they provide food outdoor step well quarante
#
#             created_at  likes  text length  polarity sentiment  target  \
# 0  2020-03-23 16:17:58      1           57       0.4  positive       1
# 1  2020-03-23 16:17:49      0           13       0.0   neutral       0
# 2  2020-03-23 16:17:44      0           38       0.0   neutral       0
# 3  2020-03-23 13:50:06      0           32       0.0   neutral       0
# 4  2020-03-23 16:17:43      0           44       0.0   neutral       0
#
#    word count
# 0           9
# 1           3
# 2           6
# 3           5
# 4           7

# %% [markdown]
# ## Model Building

# %%
# BOW (bag of words)
##
cv = CountVectorizer(analyzer='word')

cv.fit(tweets['text'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
# Preview vocabulary and the number of vocab words
##
print(len(cv.vocabulary_))
# Out:
# 1958

# %%
cv.vocabulary_
# Out:
# {'everyday': 580,
#  'might': 1072,
#  'good': 724,
#  'there': 1724,
#  'always': 58,
#  'something': 1599,
#  'day': 420,
#  'could': 374,
#  'next': 1142,
#  'one': 1177,
#  'week': 1893,
#  'imagine': 828,
#  'people': 1226,
#  'coming': 322,
#  'self': 1522,
#  'never': 1139,
#  'forget': 682,
#  'remind': 1413,
#  'fight': 641,
#  'corona': 370,
#  'they': 1726,
#  'provide': 1340,
#  'food': 669,
#  'outdoor': 1190,
#  'step': 1636,
#  'well': 1897,
#  'quarante': 1349,
#  'like': 963,
#  'said': 1480,
#  'total': 1757,
#  'shutdown': 1558,
#  'bite': 190,
#  'finger': 651,
#  'since': 1570,
#  'childhood': 290,
#  'seen': 1519,
#  'big': 180,
#  'need': 1131,
#  'testing': 1715,
#  'army': 100,
#  'threat': 1734,
#  'national': 1122,
#  'se': 1506,
#  'wish': 1917,
#  'would': 1941,
#  'much': 1110,
#  'presidential': 1300,
#  'address': 19,
#  'waiting': 1867,
#  'today': 1748,
#  'mass': 1038,
#  'please': 1259,
#  'way': 1888,
#  'help': 778,
#  'mean': 1047,
#  'na': 1117,
#  'cure': 399,
#  'money': 1099,
#  'anaemic': 67,
#  'difficult': 464,
#  'chose': 298,
#  'dying': 515,
#  'hunger': 817,
#  'still': 1638,
#  'open': 1178,
#  'whatever': 1901,
#  'taken': 1696,
#  'last': 934,
#  'buy': 240,
#  'gas': 705,
#  'different': 463,
#  'life': 961,
#  'normal': 1151,
#  'outside': 1191,
#  'hope': 802,
#  'see': 1515,
#  'government': 729,
#  'fuel': 693,
#  'order': 1183,
#  'charge': 282,
#  'fare': 623,
#  'counter': 376,
#  'productive': 1322,
#  'safe': 1478,
#  'stop': 1642,
#  'spread': 1617,
#  'escapade': 566,
#  'country': 378,
#  'urge': 1831,
#  'fellow': 634,
#  'adhere': 21,
#  'remember': 1412,
#  'issue': 897,
#  'can': 248,
#  'dont': 498,
#  'understand': 1814,
#  'pleading': 1258,
#  'threaten': 1735,
#  'hi': 784,
#  'confirmed': 346,
#  'case': 262,
#  'eating': 524,
#  'june': 908,
#  'watching': 1884,
#  'holy': 796,
#  'courtesy': 381,
#  'real': 1369,
#  'sash': 1490,
#  'got': 727,
#  'boxing': 210,
#  'old': 1175,
#  'face': 611,
#  'many': 1032,
#  'isolation': 896,
#  'enough': 556,
#  'staff': 1623,
#  'revolution': 1448,
#  'were': 1899,
#  'may': 1044,
#  'unravel': 1827,
#  'feed': 630,
#  'time': 1742,
#  'want': 1873,
#  'poor': 1267,
#  'society': 1592,
#  'even': 574,
#  'cook': 366,
#  'recipe': 1378,
#  'listen': 972,
#  'banter': 146,
#  'lot': 1003,
#  'exclusive': 589,
#  'music': 1113,
#  'ready': 1368,
#  'starting': 1628,
#  'tomorrow': 1753,
#  'stay': 1633,
#  'indoors': 854,
#  'impressive': 841,
#  'seeing': 1516,
#  'valley': 1839,
#  'arcade': 97,
#  'proper': 1328,
#  'screening': 1504,
#  'everyone': 581,
#  'going': 722,
#  'sale': 1483,
#  'call': 243,
#  'ask': 110,
#  'seek': 1517,
#  'aid': 44,
#  'patience': 1216,
#  'prayer': 1286,
#  'world': 1933,
#  'religion': 1407,
#  'fighting': 642,
#  'ignorance': 825,
#  'consider': 349,
#  'remain': 1411,
#  'low': 1007,
#  'reduce': 1387,
#  'price': 1308,
#  'start': 1627,
#  'earning': 518,
#  'daily': 409,
#  'phone': 1241,
#  'kindly': 920,
#  'send': 1524,
#  'chat': 284,
#  'st': 1621,
#  'county': 379,
#  'woman': 1924,
#  'recently': 1377,
#  'returned': 1442,
#  'forced': 674,
#  'freely': 688,
#  'pray': 1285,
#  'medical': 1053,
#  'logic': 989,
#  'behind': 172,
#  'gap': 704,
#  'bathroom': 153,
#  'hullabaloo': 813,
#  'anyone': 80,
#  'fierce': 640,
#  'co': 313,
#  'thinking': 1730,
#  'min': 1080,
#  'you': 1951,
#  'right': 1453,
#  'go': 719,
#  'landscape': 931,
#  'came': 246,
#  'morning': 1103,
#  'found': 685,
#  'tree': 1786,
#  'kitchen': 922,
#  'window': 1913,
#  'set': 1532,
#  'scorching': 1502,
#  'sun': 1670,
#  'every': 578,
#  'end': 550,
#  'family': 619,
#  'bob': 200,
#  'smoking': 1590,
#  'looming': 995,
#  'crisis': 389,
#  'marketing': 1035,
#  'surviving': 1683,
#  'sex': 1535,
#  'die': 460,
#  'protected': 1334,
#  'handshake': 752,
#  'meanwhile': 1050,
#  'mute': 1115,
#  'heat': 772,
#  'pandemonium': 1202,
#  'explain': 599,
#  'let': 958,
#  'follow': 667,
#  'obligation': 1163,
#  'save': 1491,
#  'home': 797,
#  'rich': 1450,
#  'mobilized': 1095,
#  'proverbial': 1339,
#  'straw': 1648,
#  'broke': 223,
#  'awake': 132,
#  'fast': 625,
#  'reliable': 1405,
#  'move': 1107,
#  'especially': 568,
#  'data': 417,
#  'information': 861,
#  'look': 991,
#  'increase': 849,
#  'availability': 126,
#  'clean': 305,
#  'water': 1885,
#  'bill': 183,
#  'curb': 398,
#  'spreading': 1618,
#  'president': 1299,
#  'giving': 715,
#  'pressed': 1302,
#  'middle': 1070,
#  'talk': 1698,
#  'private': 1313,
#  'sector': 1513,
#  'partnership': 1209,
#  'red': 1385,
#  'hand': 748,
#  'shake': 1537,
#  'neighborhood': 1135,
#  'friend': 689,
#  'boy': 211,
#  'deal': 425,
#  'worse': 1937,
#  'cause': 270,
#  'made': 1011,
#  'bless': 195,
#  'surely': 1677,
#  'come': 320,
#  'really': 1371,
#  'truthful': 1798,
#  'number': 1159,
#  'believe': 173,
#  'tramp': 1770,
#  'update': 1830,
#  'suspended': 1686,
#  'air': 45,
#  'depending': 443,
#  'sabine': 1475,
#  'joy': 905,
#  'closed': 312,
#  'shall': 1539,
#  'leave': 953,
#  'alone': 53,
#  'worst': 1939,
#  'scenario': 1499,
#  'get': 711,
#  'point': 1262,
#  'mad': 1010,
#  'deputy': 446,
#  'governor': 730,
#  'contact': 356,
#  'taking': 1697,
#  'avoid': 130,
#  'project': 1326,
#  'construct': 355,
#  'human': 814,
#  'mind': 1081,
#  'manifested': 1029,
#  'two': 1808,
#  'lock': 986,
#  'hide': 785,
#  'little': 976,
#  'feel': 632,
#  'refreshing': 1391,
#  'news': 1141,
#  'use': 1834,
#  'majority': 1020,
#  'work': 1929,
#  'connection': 348,
#  'touch': 1759,
#  'lady': 928,
#  'carelessness': 257,
#  'cost': 372,
#  'dearly': 427,
#  'learn': 949,
#  'financial': 647,
#  'discipline': 475,
#  'accountability': 9,
#  'reason': 1372,
#  'keep': 911,
#  'search': 1507,
#  'catholic': 268,
#  'priest': 1309,
#  'also': 56,
#  'basically': 152,
#  'expire': 598,
#  'date': 418,
#  'public': 1343,
#  'transport': 1774,
#  'scale': 1496,
#  'critical': 390,
#  'nation': 1121,
#  'th': 1717,
#  'hard': 757,
#  'headed': 764,
#  'spring': 1619,
#  'university': 1822,
#  'took': 1755,
#  'ominous': 1176,
#  'hitchhiker': 791,
#  'tested': 1714,
#  'positive': 1272,
#  'write': 1942,
#  'grateful': 734,
#  'soldier': 1593,
#  'web': 1892,
#  'interconnection': 880,
#  'beginning': 170,
#  'suspect': 1684,
#  'pastor': 1214,
#  'back': 137,
#  'put': 1346,
#  'mandatory': 1027,
#  'hospital': 806,
#  'state': 1630,
#  'directive': 469,
#  'feeding': 631,
#  'accurate': 10,
#  'afraid': 36,
#  'workplace': 1932,
#  'simplifies': 1568,
#  'approach': 93,
#  'watch': 1882,
#  'video': 1849,
#  'mahatma': 1013,
#  'around': 101,
#  'science': 1501,
#  'nowadays': 1158,
#  'hear': 769,
#  'prime': 1311,
#  'god': 721,
#  'catastrophe': 266,
#  'year': 1946,
#  'lord': 999,
#  'say': 1494,
#  'offer': 1169,
#  'wash': 1877,
#  'second': 1510,
#  'chance': 277,
#  'think': 1728,
#  'laugh': 938,
#  'track': 1766,
#  'without': 1922,
#  'saying': 1495,
#  'an': 66,
#  'listening': 973,
#  'doctor': 491,
#  'explaining': 600,
#  'practice': 1284,
#  'better': 178,
#  'established': 570,
#  'led': 956,
#  'burial': 235,
#  'march': 1033,
#  'replace': 1420,
#  'account': 8,
#  'card': 252,
#  'cheque': 288,
#  'chase': 283,
#  'paper': 1204,
#  'knew': 923,
#  'tissue': 1745,
#  'bring': 221,
#  'change': 278,
#  'local': 982,
#  'shopkeeper': 1550,
#  'support': 1672,
#  'safety': 1479,
#  'shop': 1549,
#  'alcohol': 49,
#  'based': 150,
#  'great': 735,
#  'job': 901,
#  'introduce': 887,
#  'voluntary': 1861,
#  'pa': 1196,
#  'vulnerable': 1863,
#  'basic': 151,
#  'income': 846,
#  'vat': 1842,
#  'essential': 569,
#  'give': 713,
#  'repent': 1418,
#  'return': 1441,
#  'showing': 1556,
#  'dispensations': 483,
#  'earth': 519,
#  'damn': 410,
#  'entire': 561,
#  'dear': 426,
#  'ex': 584,
#  'mate': 1042,
#  'core': 368,
#  'do': 490,
#  'complete': 332,
#  'ram': 1359,
#  'inch': 844,
#  'monitor': 1100,
#  'currently': 402,
#  'intimate': 886,
#  'panic': 1203,
#  'casual': 264,
#  'born': 206,
#  'resist': 1427,
#  'research': 1425,
#  'virus': 1854,
#  'long': 990,
#  'civil': 302,
#  'probably': 1315,
#  'assured': 115,
#  'month': 1102,
#  'first': 653,
#  'praying': 1287,
#  'rejoice': 1397,
#  'active': 16,
#  'didn': 459,
#  'rely': 1410,
#  'make': 1021,
#  'far': 622,
#  'shaken': 1538,
#  'weather': 1891,
#  'third': 1731,
#  'heal': 765,
#  'following': 668,
#  'social': 1591,
#  'dry': 510,
#  'spell': 1614,
#  'mental': 1063,
#  'illness': 827,
#  'what': 1900,
#  'reducing': 1388,
#  'single': 1573,
#  'given': 714,
#  'guy': 745,
#  'happy': 756,
#  'estate': 571,
#  'dispense': 484,
#  'selfish': 1523,
#  'surge': 1678,
#  'power': 1280,
#  'per': 1227,
#  'unit': 1819,
#  'everything': 582,
#  'stand': 1625,
#  'wont': 1927,
#  'affect': 31,
#  'le': 941,
#  'pollution': 1266,
#  'due': 511,
#  'transportation': 1775,
#  'mining': 1083,
#  'mother': 1104,
#  'healing': 766,
#  'pain': 1200,
#  'gain': 702,
#  'indefinitely': 852,
#  'result': 1438,
#  'am': 59,
#  'ago': 39,
#  'serious': 1529,
#  'danger': 413,
#  'unity': 1821,
#  'determination': 456,
#  'protect': 1333,
#  'solidarity': 1594,
#  'enforce': 552,
#  'south': 1609,
#  'ca': 241,
#  'grow': 741,
#  'that': 1721,
#  'nature': 1125,
#  'heavy': 773,
#  'article': 106,
#  'new': 1140,
#  'asymptomatic': 116,
#  'trigger': 1788,
#  'round': 1466,
#  'infection': 857,
#  'visit': 1857,
#  'click': 309,
#  'link': 968,
#  'thank': 1718,
#  'later': 935,
#  'someone': 1598,
#  'become': 162,
#  'test': 1713,
#  'firing': 652,
#  'flood': 661,
#  'win': 1912,
#  'application': 90,
#  'andros': 70,
#  'best': 177,
#  'graphics': 733,
#  'wait': 1865,
#  'hurriedly': 819,
#  'lips': 971,
#  'bird': 187,
#  'amazing': 61,
#  'angry': 71,
#  'million': 1078,
#  'trusting': 1796,
#  'kill': 917,
#  'elderly': 538,
#  'production': 1321,
#  'washed': 1878,
#  'kept': 915,
#  'distance': 488,
#  'street': 1650,
#  'definitely': 435,
#  'tax': 1703,
#  'rate': 1362,
#  'know': 924,
#  'place': 1251,
#  'ground': 740,
#  'floor': 662,
#  'rule': 1470,
#  'procedure': 1317,
#  'thought': 1733,
#  'moderate': 1096,
#  'humble': 816,
#  'request': 1423,
#  'note': 1154,
#  'abroad': 2,
#  'must': 1114,
#  'company': 328,
#  'namely': 1119,
#  'equity': 565,
#  'bank': 144,
#  'cotton': 373,
#  'raising': 1358,
#  'health': 767,
#  'ministry': 1085,
#  'washing': 1879,
#  'record': 1381,
#  'international': 884,
#  'police': 1264,
#  'ni': 1143,
#  'additional': 18,
#  'sure': 1676,
#  'install': 871,
#  'success': 1662,
#  'welcome': 1896,
#  'option': 1181,
#  'level': 960,
#  'three': 1737,
#  'trip': 1789,
#  'prevention': 1307,
#  'encourage': 549,
#  'feat': 629,
#  'proud': 1337,
#  'sceptic': 1500,
#  'take': 1695,
#  'recover': 1383,
#  'latest': 936,
#  'epidemic': 562,
#  'outbreak': 1189,
#  'yesterday': 1948,
#  'aged': 38,
#  'man': 1026,
#  'village': 1851,
#  'body': 201,
#  'rest': 1435,
#  'wrong': 1944,
#  'pas': 1210,
#  'roughly': 1465,
#  'working': 1931,
#  'cut': 406,
#  'speech': 1613,
#  'joke': 903,
#  'nothing': 1156,
#  'documentary': 492,
#  'ego': 534,
#  'channel': 279,
#  'subscribe': 1661,
#  'fear': 628,
#  'strong': 1654,
#  'observe': 1164,
#  'evening': 575,
#  'pick': 1244,
#  'happening': 755,
#  'press': 1301,
#  'bringing': 222,
#  'discuss': 478,
#  'care': 253,
#  'provided': 1341,
#  'handling': 751,
#  'delay': 437,
#  'disrupt': 487,
#  'education': 529,
#  'some': 1596,
#  'revision': 1446,
#  'play': 1256,
#  'store': 1645,
#  'extended': 607,
#  'produce': 1319,
#  'product': 1320,
#  'whose': 1908,
#  'share': 1542,
#  'live': 977,
#  'streaming': 1649,
#  'became': 161,
#  'sweet': 1689,
#  'inside': 869,
#  'effective': 531,
#  'spirit': 1616,
#  'tell': 1708,
#  'painful': 1201,
#  'sad': 1476,
#  'expensive': 597,
#  'pack': 1197,
#  'vile': 1850,
#  'nice': 1144,
#  'plan': 1253,
#  'sorted': 1605,
#  'net': 1137,
#  'flatten': 658,
#  'curve': 404,
#  'comfortable': 321,
#  'getting': 712,
#  'infected': 856,
#  'common': 326,
#  'sense': 1526,
#  'trying': 1800,
#  'prove': 1338,
#  'church': 299,
#  'service': 1531,
#  'necessary': 1129,
#  'rather': 1363,
#  'bench': 176,
#  'marking': 1036,
#  'buds': 230,
#  'male': 1025,
#  'counterpart': 377,
#  'zero': 1955,
#  'touched': 1760,
#  'community': 327,
#  'volunteer': 1862,
#  'campaign': 247,
#  'similar': 1566,
#  'identify': 823,
#  'advised': 28,
#  'invest': 891,
#  'drink': 504,
#  'sweat': 1688,
#  'making': 1024,
#  'honestly': 799,
#  'among': 64,
#  'preside': 1298,
#  'concert': 338,
#  'tonight': 1754,
#  'hello': 777,
#  'check': 286,
#  'ar': 96,
#  'another': 76,
#  'looking': 993,
#  'export': 603,
#  'doesn': 494,
#  'close': 311,
#  'version': 1846,
#  'driver': 506,
#  'china': 292,
#  'high': 786,
#  'handy': 753,
#  'agreement': 41,
#  'access': 5,
#  'apart': 83,
#  'cart': 261,
#  'voice': 1859,
#  'telling': 1709,
#  'sit': 1576,
#  'mighty': 1073,
#  'intelligence': 876,
#  'shamelessly': 1541,
#  'director': 470,
#  'association': 113,
#  'men': 1061,
#  'emotional': 544,
#  'wife': 1909,
#  'exaggeration': 586,
#  'saw': 1493,
#  'near': 1126,
#  'rolled': 1461,
#  'pay': 1220,
#  'rent': 1417,
#  'focus': 666,
#  'minor': 1086,
#  'accident': 6,
#  'true': 1793,
#  'seriously': 1530,
#  'column': 317,
#  'according': 7,
#  'patient': 1217,
#  'package': 1198,
#  'sugar': 1666,
#  'rice': 1449,
#  'maize': 1019,
#  'flour': 663,
#  'wheat': 1902,
#  'meet': 1057,
#  'fun': 698,
#  'side': 1562,
#  'ha': 746,
#  'part': 1208,
#  'situation': 1578,
#  'soon': 1601,
#  'jump': 907,
#  'build': 231,
#  'training': 1769,
#  'hotel': 809,
#  'expose': 604,
#  'top': 1756,
#  'official': 1172,
#  'advocate': 30,
#  'conjunction': 347,
#  'repentance': 1419,
#  'reconciliation': 1380,
#  'person': 1236,
#  'totally': 1758,
#  'calm': 245,
#  'deep': 432,
#  'choice': 295,
#  'careless': 255,
#  'statement': 1632,
#  'hit': 790,
#  'ride': 1451,
#  'limousine': 965,
#  'packed': 1199,
#  'large': 933,
#  'volume': 1860,
#  'higher': 787,
#  'risk': 1458,
#  'gender': 707,
#  'exposed': 605,
#  'difference': 462,
#  'eat': 523,
#  'spend': 1615,
#  'together': 1749,
#  'along': 54,
#  'forever': 681,
#  'memory': 1060,
#  'goal': 720,
#  'choose': 297,
#  'armed': 99,
#  'force': 673,
#  'already': 55,
#  'sensitization': 1527,
#  'rotary': 1464,
#  'message': 1067,
#  'up': 1829,
#  'sick': 1561,
#  'text': 1716,
#  'affected': 32,
#  'cannot': 249,
#  'trash': 1776,
#  'now': 1157,
#  'enigma': 554,
#  'told': 1751,
#  'donate': 496,
#  'faster': 626,
#  'network': 1138,
#  'flight': 660,
#  'duty': 513,
#  'cash': 263,
#  'detain': 455,
#  'auction': 119,
#  'belonging': 174,
#  'coverage': 383,
#  'worth': 1940,
#  'appreciate': 92,
#  'litigation': 975,
#  'measure': 1051,
#  'apocalyptic': 84,
#  'vaccine': 1838,
#  'till': 1741,
#  'almost': 52,
#  'instead': 873,
#  'dating': 419,
#  'context': 360,
#  'economic': 525,
#  'important': 836,
#  'overlook': 1193,
#  'citizens': 300,
#  'impose': 837,
#  'balloon': 142,
#  'space': 1610,
#  'match': 1041,
#  'movie': 1109,
#  'trivial': 1791,
#  'fine': 650,
#  'apparently': 86,
#  'slaying': 1581,
#  'landing': 929,
#  'impact': 834,
#  'unimaginable': 1818,
#  'example': 587,
#  'death': 428,
#  'gave': 706,
#  'bread': 216,
#  'brain': 213,
#  'final': 645,
#  'minute': 1087,
#  'branch': 214,
#  'lobby': 981,
#  'survival': 1681,
#  'trust': 1795,
#  'technology': 1707,
#  'nightmare': 1146,
#  'economy': 527,
#  'temporary': 1710,
#  'waiter': 1866,
#  'running': 1472,
#  'easy': 522,
#  'contain': 358,
#  'makeshift': 1023,
#  'condemning': 341,
#  'crossed': 392,
#  'jack': 900,
#  'living': 978,
#  'hilarious': 789,
#  'sanitize': 1489,
#  'run': 1471,
#  'chloroquine': 294,
#  'system': 1693,
#  'bounce': 209,
#  'negative': 1132,
#  'supposed': 1673,
#  'religious': 1409,
#  'differ': 461,
#  'footstep': 672,
#  'oh': 1174,
#  'york': 1950,
#  'perfectly': 1230,
#  'hell': 776,
#  'thing': 1727,
#  'done': 497,
#  'announcement': 74,
#  'timing': 1743,
#  'afford': 35,
#  'decent': 429,
#  'disease': 479,
#  'physician': 1243,
#  'fuller': 695,
#  'shutting': 1559,
#  'lower': 1008,
#  'twitter': 1807,
#  'pressure': 1303,
#  'early': 517,
#  'depressed': 444,
#  'mentality': 1064,
#  'complaint': 331,
#  'slightly': 1583,
#  'paranoid': 1207,
#  'try': 1799,
#  'highly': 788,
#  'inflammable': 858,
#  'natural': 1124,
#  'flattening': 659,
#  'mummy': 1112,
#  'chemical': 287,
#  'within': 1921,
#  'either': 536,
#  'heed': 774,
#  'learned': 950,
#  'carrying': 260,
#  'disgrace': 480,
#  'harmful': 759,
#  'young': 1952,
#  'decided': 431,
#  'influence': 859,
#  'talking': 1699,
#  'wonderful': 1925,
#  'lead': 942,
#  'been': 166,
#  'shortly': 1552,
#  'break': 217,
#  'revelation': 1444,
#  'unfair': 1816,
#  'struggling': 1655,
#  'yet': 1949,
#  'be': 157,
#  'bus': 237,
#  'rising': 1457,
#  'yes': 1947,
#  'providing': 1342,
#  'electricity': 539,
#  'movement': 1108,
#  'kit': 921,
#  'pope': 1268,
#  'exile': 593,
#  'breaking': 219,
#  'source': 1608,
#  'short': 1551,
#  'night': 1145,
#  'slapping': 1580,
#  'mill': 1077,
#  'create': 386,
#  'pretend': 1304,
#  'find': 648,
#  'solution': 1595,
#  'continue': 361,
#  'increasing': 850,
#  'smoker': 1589,
#  'fully': 696,
#  'light': 962,
#  'tunnel': 1803,
#  'busy': 239,
#  'tu': 1801,
#  'present': 1297,
#  'medium': 1056,
#  'quick': 1351,
#  'blame': 192,
#  'adviser': 29,
#  'brookside': 225,
#  'and': 69,
#  'business': 238,
#  'supermarket': 1671,
#  'forcing': 676,
#  'blank': 194,
#  'stupid': 1657,
#  'flying': 665,
#  'ensure': 557,
#  'respect': 1430,
#  'double': 500,
#  'name': 1118,
#  'thanks': 1720,
#  'loan': 980,
#  'chain': 274,
#  'idiot': 824,
#  'travelled': 1780,
#  'plead': 1257,
#  'destroy': 454,
#  'calling': 244,
#  'emergency': 543,
#  'conference': 344,
#  'emulated': 548,
#  'forceful': 675,
#  'traveling': 1779,
#  'traveled': 1778,
#  'objective': 1162,
#  'progress': 1325,
#  'add': 17,
#  'initiate': 865,
#  'exit': 595,
#  'door': 499,
#  'imposing': 838,
#  'unfordable': 1817,
#  'small': 1586,
#  'reminder': 1414,
#  'beauty': 160,
#  'fumigation': 697,
#  'fantastic': 621,
#  'hey': 783,
#  'weigh': 1895,
#  'inner': 866,
#  'gloomy': 718,
#  'lose': 1000,
#  'cruel': 396,
#  'employer': 547,
#  'seem': 1518,
#  'biggest': 182,
#  'pillar': 1247,
#  'resource': 1429,
#  'equipment': 564,
#  ...}

# %%
# Example transforming a single text
##
print(cv.transform([tweets['text'][0]]))
# Out:
#   (0, 58)	1
#   (0, 374)	1
#   (0, 420)	1
#   (0, 580)	1
#   (0, 724)	2
#   (0, 1072)	1
#   (0, 1599)	1
#   (0, 1724)	1

# %%
# Example getting the feature name by index
##
cv.get_feature_names()[724]
# Out:
# 'good'

# %%
# Transforming the whole BOW to a sparse matrix
##
bow_text = cv.transform(tweets['text'])

# %%
# Non-zero occurrences
##
bow_text.nnz
# Out:
# 6455

# %%
# tfidf weighting
##
tfidf_transformer = TfidfTransformer()

tfidf_transformer.fit(bow_text)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
# Example transforming a single bow
##
print(tfidf_transformer.transform(cv.transform([tweets['text'][0]])))
# Out:
#   (0, 1724)	0.3537881182770148
#   (0, 1599)	0.31966304511247007
#   (0, 1072)	0.31025800282988647
#   (0, 724)	0.5665166663853541
#   (0, 580)	0.37661555463428
#   (0, 420)	0.28325833319267707
#   (0, 374)	0.1665231693082509
#   (0, 58)	0.32502894965067836

# %%
# Example getting idf weight of a word
##
tfidf_transformer.idf_[cv.vocabulary_['good']]
# Out:
# 5.0312864262549635

# %%
# Transforming the whole sparse matrix
##
tfidf_text = tfidf_transformer.transform(bow_text)

# %% [markdown]
# Adding 'text length' and 'word count' as features to the model
# We'll stack the features to the sparse matrix horizontally

# %%
# Transforming the two columns into sparse matrices
##
txt_length = coo_matrix(tweets['text length']).reshape(1182,1)
wrd_cnt = coo_matrix(tweets['word count']).reshape(1182,1)

features = hstack([tfidf_text, txt_length, wrd_cnt])

# Preview difference in shapes
print("Shape of text column sparse matrix: ", tfidf_text.shape)
print("Shape of concatenated features sparse matrix: ", features.shape)
# Out:
# Shape of text column sparse matrix:  (1182, 1958)
# Shape of concatenated features sparse matrix:  (1182, 1960)

# %% [markdown]
# ## Comparing different classification models:
# - Logistic Regression
# - Linear SVC (svm)
# - Random Forest Classifier
# - Xgboost Classifier

# %%
# Splitting data into train and test splits
##
X_train, X_test, y_train, y_test = train_test_split(features, tweets['target'], test_size=0.3)

# %%
# Initialize models
##
lr = LogisticRegression(C=2.0, class_weight=None, dual=False, max_iter=100)

svc = LinearSVC(C=2.0, class_weight=None, dual=False, max_iter=100)

rfc = RandomForestClassifier(bootstrap=False, class_weight=None, 
                             criterion='entropy', min_samples_split=6, n_estimators=160, warm_start=False)

xgb = xgb.XGBClassifier(objective='multi:softmax', num_class=3)

# %%
# Train models
##
lr.fit(X_train, y_train)

svc.fit(X_train, y_train)

rfc.fit(X_train, y_train)

xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_class=3, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method=None, validate_parameters=False, verbosity=None)

# %%
# Make predictions
##
lr_pred = lr.predict(X_test)

svc_pred = svc.predict(X_test)

rfc_pred = rfc.predict(X_test)

xgb_pred = xgb.predict(X_test)

# %%
# Evaluate models
##
print("Logistic Regression \n----------------------------------")
print(confusion_matrix(y_test, lr_pred))
print(classification_report(y_test, lr_pred))
print("Linear SVC \n---------------------------------")
print(confusion_matrix(y_test, svc_pred))
print(classification_report(y_test, svc_pred))
print("Random Forest Classifier \n----------------------------------")
print(confusion_matrix(y_test, rfc_pred))
print(classification_report(y_test, rfc_pred))
print("Xgboost Classifier \n----------------------------------")
print(confusion_matrix(y_test, xgb_pred))
print(classification_report(y_test, xgb_pred))
# Out:
# Logistic Regression
# ----------------------------------
# [[  5  34   5]
#  [  2 190  11]
#  [  1  47  60]]
#               precision    recall  f1-score   support
#
#           -1       0.62      0.11      0.19        44
#            0       0.70      0.94      0.80       203
#            1       0.79      0.56      0.65       108
#
#     accuracy                           0.72       355
#    macro avg       0.71      0.54      0.55       355
# weighted avg       0.72      0.72      0.68       355
#
# Linear SVC
# ---------------------------------
# [[ 18  21   5]
#  [  6 179  18]
#  [  3  33  72]]
#               precision    recall  f1-score   support
#
#           -1       0.67      0.41      0.51        44
#            0       0.77      0.88      0.82       203
#            1       0.76      0.67      0.71       108
#
#     accuracy                           0.76       355
#    macro avg       0.73      0.65      0.68       355
# weighted avg       0.75      0.76      0.75       355
#
# Random Forest Classifier
# ----------------------------------
# [[ 10  28   6]
#  [  4 192   7]
#  [  4  50  54]]
#               precision    recall  f1-score   support
#
#           -1       0.56      0.23      0.32        44
#            0       0.71      0.95      0.81       203
#            1       0.81      0.50      0.62       108
#
#     accuracy                           0.72       355
#    macro avg       0.69      0.56      0.58       355
# weighted avg       0.72      0.72      0.69       355
#
# Xgboost Classifier
# ----------------------------------
# [[  9  30   5]
#  [ 12 180  11]
#  [  8  30  70]]
#               precision    recall  f1-score   support
#
#           -1       0.31      0.20      0.25        44
#            0       0.75      0.89      0.81       203
#            1       0.81      0.65      0.72       108
#
#     accuracy                           0.73       355
#    macro avg       0.62      0.58      0.59       355
# weighted avg       0.71      0.73      0.71       355

# %%
cross_val_score(xgb, features, tweets['target'], cv=5)
# Out:
# array([0.71428571, 0.70588235, 0.74576271, 0.71489362, 0.67234043])

# %%
# Making sure that the models are not overfitting using cross val score metric with 5 folds
##
print("Logistic Regression \n------------------------- \nscore= ", cross_val_score(lr, features, tweets['target'], cv=5).mean())
print("\nLinear SVC \n------------------------- \nscore=", cross_val_score(svc, features, tweets['target'], cv=5).mean())
print("\nRandom Forest Classifier \n------------------------- \nscore=", cross_val_score(rfc, features, tweets['target'], cv=5).mean())
print("\nXgboost Classifier \n------------------------- \nscore=", cross_val_score(xgb, features, tweets['target'], cv=5).mean())
# Out:
# Logistic Regression
# -------------------------
# score=  0.691191289353823
#
# Linear SVC
# -------------------------
# score= 0.7521528120804759
#
# Random Forest Classifier
# -------------------------
# score= 0.7309297638997899
#
# Xgboost Classifier
# -------------------------
# score= 0.7106329643288978

# %%
# Linear SVC performed best
# That's a good score having in mind that the model is attempting to predict between three categories/classes
